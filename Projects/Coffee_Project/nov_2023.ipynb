# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
csv_path = 'nov_2023_sales.csv'


coffee_df = pd.read_csv(csv_path)
coffee_df.head(25)
# Out:
#     LocationNumber LocationName  Group1 Quantity1    Amount1 Textbox2  \
# 0               36     Eastland  Coffee     2,394  10,480.64   31.18%
# 1               36     Eastland  Coffee     2,394  10,480.64   31.18%
# 2               36     Eastland  Coffee     2,394  10,480.64   31.18%
# 3               36     Eastland  Coffee     2,394  10,480.64   31.18%
# 4               36     Eastland  Coffee     2,394  10,480.64   31.18%
# 5               36     Eastland  Coffee     2,394  10,480.64   31.18%
# 6               36     Eastland  Coffee     2,394  10,480.64   31.18%
# 7               36     Eastland  Coffee     2,394  10,480.64   31.18%
# 8               36     Eastland  Coffee     2,394  10,480.64   31.18%
# 9               36     Eastland  Coffee     2,394  10,480.64   31.18%
# 10              36     Eastland  Coffee     2,394  10,480.64   31.18%
# 11              36     Eastland  Coffee     2,394  10,480.64   31.18%
# ...

# %%
drop_columns = ['LocationNumber', 'LocationName']
coffee_df = coffee_df.drop(columns=drop_columns, errors='ignore')
coffee_df.head()
# Out:
#    Group1 Quantity1    Amount1 Textbox2     Description  Quantity  Amount  \
# 0  Coffee     2,394  10,480.64   31.18%  Cappuccino Sml       176  686.75
# 1  Coffee     2,394  10,480.64   31.18%  Flat White Cup       117  463.91
# 2  Coffee     2,394  10,480.64   31.18%  Flat White Mug       109  500.38
# 3  Coffee     2,394  10,480.64   31.18%  Flat White Sml        61  244.45
# 4  Coffee     2,394  10,480.64   31.18%     Latte Glass       204  821.78
#
#   Textbox13 txtTotalSales
# 0     8,912     33,612.72
# 1     8,912     33,612.72
# 2     8,912     33,612.72
# 3     8,912     33,612.72
# 4     8,912     33,612.72

# %%
coffee = coffee_df[coffee_df['Group1'] == 'Coffee']
coffee
# Out:
#     Group1 Quantity1    Amount1 Textbox2          Description  Quantity  \
# 0   Coffee     2,394  10,480.64   31.18%       Cappuccino Sml       176
# 1   Coffee     2,394  10,480.64   31.18%       Flat White Cup       117
# 2   Coffee     2,394  10,480.64   31.18%       Flat White Mug       109
# 3   Coffee     2,394  10,480.64   31.18%       Flat White Sml        61
# 4   Coffee     2,394  10,480.64   31.18%          Latte Glass       204
# 5   Coffee     2,394  10,480.64   31.18%       Long Black Cup        20
# 6   Coffee     2,394  10,480.64   31.18%       Long Black Lrg         2
# 7   Coffee     2,394  10,480.64   31.18%       Long Black Med         7
# 8   Coffee     2,394  10,480.64   31.18%            Mocha Lrg        13
# 9   Coffee     2,394  10,480.64   31.18%            Mocha Sml        24
# 10  Coffee     2,394  10,480.64   31.18%      Short Black D/I         3
# 11  Coffee     2,394  10,480.64   31.18%  Short Macchiato T/A         3
# ...

# %%
coffee.Description.info()
# Out:
# <class 'pandas.core.series.Series'>
# Index: 31 entries, 0 to 30
# Series name: Description
# Non-Null Count  Dtype
# --------------  -----
# 31 non-null     object
# dtypes: object(1)
# memory usage: 496.0+ bytes

# %%
coffee.sort_values(by='Description', ascending=True)
# Out:
#     Group1 Quantity1    Amount1 Textbox2          Description  Quantity  \
# 20  Coffee     2,394  10,480.64   31.18%       Cappuccino Cup       268
# 21  Coffee     2,394  10,480.64   31.18%       Cappuccino Lrg        73
# 27  Coffee     2,394  10,480.64   31.18%       Cappuccino Med       238
# 12  Coffee     2,394  10,480.64   31.18%       Cappuccino Mug       179
# 0   Coffee     2,394  10,480.64   31.18%       Cappuccino Sml       176
# 1   Coffee     2,394  10,480.64   31.18%       Flat White Cup       117
# 28  Coffee     2,394  10,480.64   31.18%       Flat White Lrg        48
# 22  Coffee     2,394  10,480.64   31.18%       Flat White Med        88
# 2   Coffee     2,394  10,480.64   31.18%       Flat White Mug       109
# 3   Coffee     2,394  10,480.64   31.18%       Flat White Sml        61
# 4   Coffee     2,394  10,480.64   31.18%          Latte Glass       204
# 29  Coffee     2,394  10,480.64   31.18%            Latte Lrg       120
# ...
